# %% [markdown]
# <a href="https://colab.research.google.com/github/I-dev-max/data_analysis_project/blob/main/weatherDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()  # This will prompt you to upload the file from your computer
# Out:
#      <input type="file" id="files-14b3c86f-861e-4cb8-9b0f-3923007b6f3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14b3c86f-861e-4cb8-9b0f-3923007b6f3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
weatherData = pd.read_csv("weatherdata.csv")

# %%
weatherData
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      01/01/2012 0:00    -1.8              -3.9         86                4
# 1      01/01/2012 1:00    -1.8              -3.7         87                4
# 2      01/01/2012 2:00    -1.8              -3.4         89                7
# 3      01/01/2012 3:00    -1.5              -3.2         88                6
# 4      01/01/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# **Data Analysis**

# %% [markdown]
# Head

# %%
weatherData.head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01/01/2012 0:00    -1.8              -3.9         86                4
# 1  01/01/2012 1:00    -1.8              -3.7         87                4
# 2  01/01/2012 2:00    -1.8              -3.4         89                7
# 3  01/01/2012 3:00    -1.5              -3.2         88                6
# 4  01/01/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Shape :

# %%
weatherData.shape
# Out:
# (8784, 8)

# %% [markdown]
# Index

# %%
weatherData.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# Columns

# %%
weatherData.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# Types of the columns

# %%
weatherData.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# Info

# %%
weatherData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# **Q1: Find all the unique wind speed values**

# %%
weatherData.head(2)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01/01/2012 0:00    -1.8              -3.9         86                4
# 1  01/01/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
weatherData['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
weatherData['Wind Speed_km/h'].unique() #Answer
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# **Q2: Find the number of times when the weather is "exactly clear"**

# %%
weatherData.head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01/01/2012 0:00    -1.8              -3.9         86                4
# 1  01/01/2012 1:00    -1.8              -3.7         87                4
# 2  01/01/2012 2:00    -1.8              -3.4         89                7
# 3  01/01/2012 3:00    -1.5              -3.2         88                6
# 4  01/01/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
weatherData["Weather"].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#weatherData["Weather"] == "Clear"
weather_counts = weatherData[weatherData.Weather == "Clear"].value_counts()
weather_counts.shape[0] #To get the number of clear days
# Out:
# 1326

# %% [markdown]
# **Q3: Find the number of times when the wind speed was exactly 4 km/h**

# %%
#weatherData.head()
req_wind_speed = weatherData[weatherData["Wind Speed_km/h"] == 4]
req_wind_speed.shape[0]
# Out:
# 474

# %% [markdown]
# **Q4: Find out all the null values**

# %%
weatherData.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# **Q5: Rename the column name Wind Speed_km/h to wind_speed**

# %%
weatherData.rename(columns = {"Wind Speed_km/h":"wind_speed"}, inplace=True)

# %% [markdown]
# **Q6: What is the mean Visibility?**

# %%
weatherData.Visibility_km.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# **Q7: What is the standard deviation of Pressure in this data?**

# %%
weatherData.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# **Q8: What is the variance of Relative Humidity in this data?**

# %%
weatherData["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# **Q9: Find all the instances when snow was recorded**

# %%
counts_of_all_weather = weatherData.Weather.value_counts()
snow_counts = weatherData[weatherData["Weather"] == "Snow"].value_counts()
snow_counts.shape[0]
# Out:
# 390

# %% [markdown]
# **Q10: Find all the instances when wind speed is greater than 24 and visibility is 25**

# %%
two_cond = weatherData[(weatherData["wind_speed"] > 24) & (weatherData["Visibility_km"] == 25)]
two_cond.shape[0] #shape is used to get the total sum of instances when this condition is true
# Out:
# 308

# %% [markdown]
# **Q11: What is the mean value of each column for the weather condition**

# %%
#weatherData.groupby('Weather').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-af61e4bf2733> in <cell line: 1>()
# ----> 1 weatherData.groupby['Weather'].mean()
#
# TypeError: 'method' object is not subscriptable
